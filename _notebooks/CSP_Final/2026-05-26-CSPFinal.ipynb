# %% [markdown]
# ---
# layout: default
# title: CSP Final
# permalink: /CSP-Final
# ---

# %% [markdown]
# <style>
#   /* Reset the hacker theme for this page */
#   body { background: #ede8df !important; }
#   #main_content, #main_content * { color: inherit; }
#   header.site-header, footer { display: none !important; }
#
#   .pg {
#     font-family: 'Georgia', serif;
#     background: #ede8df;
#     color: #1a1a1a;
#     min-height: 100vh;
#     margin: -20px -30px;
#     padding: 0;
#   }
#
#   /* Top nav bar */
#   .pg-nav {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     padding: 1.4rem 4rem;
#     border-bottom: 1px solid #e5e0d8;
#     background: #ede8df;
#     position: sticky;
#     top: 0;
#     z-index: 100;
#   }
#   .pg-nav-name {
#     font-family: 'Georgia', serif;
#     font-size: 1.05rem;
#     letter-spacing: 0.05em;
#     color: #1a1a1a;
#   }
#   .pg-nav-links {
#     display: flex;
#     gap: 2.5rem;
#     list-style: none;
#     margin: 0; padding: 0;
#   }
#   .pg-nav-links a {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.7rem;
#     letter-spacing: 0.15em;
#     text-transform: uppercase;
#     color: #555;
#     text-decoration: none;
#   }
#   .pg-nav-links a:hover { color: #1a1a1a; }
#
#   /* Hero */
#   .pg-hero {
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     min-height: 82vh;
#     align-items: stretch;
#   }
#   .pg-hero-left {
#     padding: 5rem 4rem;
#     display: flex;
#     flex-direction: column;
#     justify-content: center;
#     border-right: 1px solid #e5e0d8;
#   }
#   .pg-hero-eyebrow {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.2em;
#     text-transform: uppercase;
#     color: #999;
#     margin-bottom: 1.5rem;
#   }
#   .pg-hero-title {
#     font-size: 3.8rem;
#     font-weight: 400;
#     line-height: 1.1;
#     color: #1a1a1a;
#     margin: 0 0 2rem;
#     letter-spacing: -0.02em;
#   }
#   .pg-hero-title em {
#     font-style: italic;
#     color: #7c6a58;
#   }
#   .pg-hero-body {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.95rem;
#     line-height: 1.8;
#     color: #555;
#     max-width: 420px;
#     margin: 0 0 2.5rem;
#   }
#   .pg-btn {
#     display: inline-block;
#     border: 1px solid #1a1a1a;
#     color: #1a1a1a;
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.18em;
#     text-transform: uppercase;
#     padding: 0.85rem 2rem;
#     text-decoration: none;
#     transition: background 0.2s, color 0.2s;
#     cursor: default;
#   }
#   .pg-btn:hover { background: #1a1a1a; color: #ede8df; }
#
#   .pg-hero-right {
#     background: #ede8e0;
#     display: flex;
#     flex-direction: column;
#     justify-content: flex-end;
#     padding: 3rem 3.5rem;
#   }
#   .pg-hero-stat-grid {
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     gap: 2rem 2.5rem;
#     margin-bottom: 2.5rem;
#   }
#   .pg-stat-num {
#     font-size: 2.8rem;
#     font-weight: 400;
#     color: #1a1a1a;
#     line-height: 1;
#     margin-bottom: 0.35rem;
#   }
#   .pg-stat-label {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.68rem;
#     letter-spacing: 0.12em;
#     text-transform: uppercase;
#     color: #7c6a58;
#   }
#   .pg-hero-quote {
#     border-top: 1px solid #c8bfb0;
#     padding-top: 1.5rem;
#     font-size: 0.85rem;
#     color: #7c6a58;
#     font-style: italic;
#     line-height: 1.7;
#   }
#
#   /* Intro strip */
#   .pg-intro {
#     display: grid;
#     grid-template-columns: 200px 1fr;
#     gap: 4rem;
#     padding: 5rem 4rem;
#     border-top: 1px solid #e5e0d8;
#     border-bottom: 1px solid #e5e0d8;
#   }
#   .pg-intro-label {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.18em;
#     text-transform: uppercase;
#     color: #999;
#     padding-top: 0.3rem;
#   }
#   .pg-intro-text {
#     font-size: 1.45rem;
#     line-height: 1.75;
#     color: #2a2a2a;
#     font-weight: 400;
#     margin: 0;
#   }
#
#   /* Trimesters */
#   .pg-trimesters { padding: 0 4rem 2rem; }
#   .pg-trim-head {
#     display: grid;
#     grid-template-columns: 200px 1fr;
#     gap: 4rem;
#     padding: 4rem 0 2rem;
#     border-top: 1px solid #e5e0d8;
#     align-items: start;
#   }
#   .pg-trim-num {
#     font-size: 4.5rem;
#     font-weight: 400;
#     color: #e5e0d8;
#     line-height: 1;
#     font-style: italic;
#   }
#   .pg-trim-info {}
#   .pg-trim-period {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.18em;
#     text-transform: uppercase;
#     color: #999;
#     margin-bottom: 0.75rem;
#   }
#   .pg-trim-title {
#     font-size: 1.9rem;
#     font-weight: 400;
#     color: #1a1a1a;
#     margin: 0 0 1.5rem;
#     line-height: 1.2;
#   }
#   .pg-trim-body {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.93rem;
#     line-height: 1.85;
#     color: #555;
#     margin: 0 0 1rem;
#   }
#   .pg-trim-body:last-child { margin-bottom: 0; }
#
#   .pg-tag-row {
#     display: flex;
#     flex-wrap: wrap;
#     gap: 0.5rem;
#     margin-top: 1.5rem;
#   }
#   .pg-tag {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.12em;
#     text-transform: uppercase;
#     border: 1px solid #c8bfb0;
#     color: #7c6a58;
#     padding: 0.3rem 0.8rem;
#   }
#
#   /* Presentation callout */
#   .pg-callout {
#     background: #1a1a1a;
#     color: #ede8df;
#     padding: 5rem 4rem;
#     margin: 3rem 0 0;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     gap: 5rem;
#     align-items: center;
#   }
#   .pg-callout-label {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.2em;
#     text-transform: uppercase;
#     color: #7c6a58;
#     margin-bottom: 1.5rem;
#   }
#   .pg-callout-title {
#     font-size: 2.4rem;
#     font-weight: 400;
#     line-height: 1.2;
#     margin: 0 0 1.5rem;
#     color: #ede8df;
#   }
#   .pg-callout-body {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.92rem;
#     line-height: 1.85;
#     color: #aaa;
#     margin: 0;
#   }
#   .pg-callout-names {
#     border-left: 2px solid #7c6a58;
#     padding-left: 1.5rem;
#   }
#   .pg-callout-names p {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.85rem;
#     color: #ccc;
#     line-height: 1.7;
#     margin: 0 0 1.5rem;
#   }
#   .pg-name-item {
#     margin-bottom: 1.2rem;
#   }
#   .pg-name-title {
#     font-size: 1.05rem;
#     color: #ede8df;
#     margin-bottom: 0.15rem;
#   }
#   .pg-name-role {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.7rem;
#     letter-spacing: 0.1em;
#     text-transform: uppercase;
#     color: #7c6a58;
#   }
#
#   /* Tools section */
#   .pg-tools {
#     padding: 5rem 4rem;
#     border-top: 1px solid #e5e0d8;
#   }
#   .pg-tools-header {
#     display: grid;
#     grid-template-columns: 200px 1fr;
#     gap: 4rem;
#     margin-bottom: 3rem;
#   }
#   .pg-tools-title {
#     font-size: 2rem;
#     font-weight: 400;
#     color: #1a1a1a;
#     margin: 0;
#   }
#   .pg-tools-grid {
#     display: grid;
#     grid-template-columns: repeat(5, 1fr);
#     border-top: 1px solid #e5e0d8;
#     border-left: 1px solid #e5e0d8;
#   }
#   .pg-tool-cell {
#     border-right: 1px solid #e5e0d8;
#     border-bottom: 1px solid #e5e0d8;
#     padding: 2rem 1.5rem;
#     transition: background 0.2s;
#   }
#   .pg-tool-cell:hover { background: #ede8e0; }
#   .pg-tool-name {
#     font-size: 1rem;
#     color: #1a1a1a;
#     margin-bottom: 0.4rem;
#   }
#   .pg-tool-desc {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.68rem;
#     color: #999;
#     letter-spacing: 0.05em;
#   }
#
#   /* Closing */
#   .pg-close {
#     padding: 6rem 4rem;
#     display: grid;
#     grid-template-columns: 1fr 1fr;
#     gap: 5rem;
#     border-top: 1px solid #e5e0d8;
#     align-items: start;
#   }
#   .pg-close-title {
#     font-size: 2.8rem;
#     font-weight: 400;
#     line-height: 1.15;
#     color: #1a1a1a;
#     margin: 0 0 0.5rem;
#   }
#   .pg-close-title em { font-style: italic; color: #7c6a58; }
#   .pg-close-sub {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.18em;
#     text-transform: uppercase;
#     color: #999;
#     margin-bottom: 2rem;
#   }
#   .pg-close-body {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.93rem;
#     line-height: 1.9;
#     color: #555;
#     margin: 0 0 1.2rem;
#   }
#
#   /* Footer strip */
#   .pg-footer {
#     background: #ede8e0;
#     padding: 2rem 4rem;
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#   }
#   .pg-footer-name {
#     font-size: 0.85rem;
#     color: #7c6a58;
#   }
#   .pg-footer-sub {
#     font-family: 'Helvetica Neue', sans-serif;
#     font-size: 0.65rem;
#     letter-spacing: 0.15em;
#     text-transform: uppercase;
#     color: #aaa;
#   }
# </style>
#
# <div class="pg">
#
#   <!-- Nav -->
#   <nav class="pg-nav">
#     <span class="pg-nav-name">Shayan Bhatti</span>
#     <ul class="pg-nav-links">
#       <li><a href="#overview">Overview</a></li>
#       <li><a href="#work">Work</a></li>
#       <li><a href="#capstone">Capstone</a></li>
#       <li><a href="#tools">Tools</a></li>
#     </ul>
#   </nav>
#
#   <!-- Hero -->
#   <section class="pg-hero" id="overview">
#     <div class="pg-hero-left">
#       <div class="pg-hero-eyebrow">Computer Science Principles &mdash; Final Reflection &mdash; 2025&ndash;2026</div>
#       <h1 class="pg-hero-title">A Year of<br><em>Building Things</em><br>That Matter</h1>
#       <p class="pg-hero-body">From writing a Snake game in trimester one to presenting a live platform to library executives in trimester three &mdash; this is the story of what a year of real software development actually looks like.</p>
#       <span class="pg-btn">Read the Full Story</span>
#     </div>
#     <div class="pg-hero-right">
#       <div class="pg-hero-stat-grid">
#         <div>
#           <div class="pg-stat-num">3</div>
#           <div class="pg-stat-label">Trimesters</div>
#         </div>
#         <div>
#           <div class="pg-stat-num">4+</div>
#           <div class="pg-stat-label">Shipped Projects</div>
#         </div>
#         <div>
#           <div class="pg-stat-num">10</div>
#           <div class="pg-stat-label">Tools Learned</div>
#         </div>
#         <div>
#           <div class="pg-stat-num">1</div>
#           <div class="pg-stat-label">Live Platform</div>
#         </div>
#       </div>
#       <div class="pg-hero-quote">
#         &ldquo;Building something is only half of it. Being able to explain it, defend your decisions, and make someone who is not a developer care about what you made &mdash; that&rsquo;s the other half.&rdquo;
#       </div>
#     </div>
#   </section>
#
#   <!-- Intro -->
#   <section class="pg-intro">
#     <div class="pg-intro-label">About This Year</div>
#     <p class="pg-intro-text">I came into this class as someone who could write code but struggled to present and communicate. I&rsquo;m leaving it with a clear picture of how software gets built in the real world &mdash; in teams, under pressure, for people outside the classroom.</p>
#   </section>
#
#   <!-- Trimesters -->
#   <div class="pg-trimesters" id="work">
#
#     <div class="pg-trim-head">
#       <div class="pg-trim-num">01</div>
#       <div class="pg-trim-info">
#         <div class="pg-trim-period">Trimester One &mdash; Fall 2025</div>
#         <h2 class="pg-trim-title">Learning to Think<br>Like a Developer</h2>
#         <p class="pg-trim-body">It started small &mdash; variables, booleans, conditionals, lists. Python one day, JavaScript the next. I built simple games like Snake, Tic Tac Toe, Flappy Bird, and GeoDash to get the fundamentals down. At the time it felt like busy work, but looking back, those foundations mattered more than I realized.</p>
#         <p class="pg-trim-body">By the end of trimester one I was writing Flask APIs and working with async JavaScript. The jump from &ldquo;variables and loops&rdquo; to &ldquo;here&rsquo;s a backend endpoint that returns data&rdquo; happened faster than I expected.</p>
#         <div class="pg-tag-row">
#           <span class="pg-tag">Python</span>
#           <span class="pg-tag">JavaScript</span>
#           <span class="pg-tag">Flask</span>
#           <span class="pg-tag">HTML &amp; CSS</span>
#         </div>
#       </div>
#     </div>
#
#     <div class="pg-trim-head">
#       <div class="pg-trim-num">02</div>
#       <div class="pg-trim-info">
#         <div class="pg-trim-period">Trimester Two &mdash; Winter 2026</div>
#         <h2 class="pg-trim-title">Moodlife &mdash;<br>First Real Product</h2>
#         <p class="pg-trim-body">My first team project was <em>Moodlife</em>, a mood and wellness tracking platform. I built a group chat system, a direct messaging feature, a full admin panel, and a facial expression recognition module using face-api.js that could detect your mood through your webcam and log it automatically.</p>
#         <p class="pg-trim-body">Working in a group for the first time was an adjustment. You have to communicate, split work properly, and trust people to deliver. It did not always go smoothly &mdash; but we shipped a real product, and I came out of it a better collaborator.</p>
#         <div class="pg-tag-row">
#           <span class="pg-tag">face-api.js</span>
#           <span class="pg-tag">Flask API</span>
#           <span class="pg-tag">Admin Panel</span>
#           <span class="pg-tag">Team Collab</span>
#         </div>
#       </div>
#     </div>
#
#   </div>
#
#   <!-- Capstone callout -->
#   <section class="pg-callout" id="capstone">
#     <div>
#       <div class="pg-callout-label">Trimester Three &mdash; Capstone &mdash; Spring 2026</div>
#       <h2 class="pg-callout-title">Friends of the Poway Library &mdash; Built From the Ground Up</h2>
#       <p class="pg-callout-body">Our team rebuilt the Friends of the Poway Library website from scratch. It went live at fopl.opencodingsociety.com. I built the core: events calendar, volunteer portal, book scanner with USB barcode support, admin dashboard, JWT authentication, and two games &mdash; a facial recognition game and Library Dodge.</p>
#     </div>
#     <div class="pg-callout-names">
#       <p>Executives from the Friends of the Poway Library attended our school presentation and reviewed everything we built. It was not a classroom demo &mdash; it was a real pitch to real stakeholders.</p>
#       <div class="pg-name-item">
#         <div class="pg-name-title">Bob Masters</div>
#         <div class="pg-name-role">Friends of the Poway Library</div>
#       </div>
#       <div class="pg-name-item">
#         <div class="pg-name-title">Kim Niehans</div>
#         <div class="pg-name-role">Friends of the Poway Library</div>
#       </div>
#       <div class="pg-name-item">
#         <div class="pg-name-title">Mark Reyes</div>
#         <div class="pg-name-role">Friends of the Poway Library</div>
#       </div>
#     </div>
#   </section>
#
#   <!-- Tools -->
#   <section class="pg-tools" id="tools">
#     <div class="pg-tools-header">
#       <div class="pg-intro-label" style="padding-top:0.5rem">Stack &amp; Skills</div>
#       <h2 class="pg-tools-title">Tools I Shipped With</h2>
#     </div>
#     <div class="pg-tools-grid">
#       <div class="pg-tool-cell"><div class="pg-tool-name">Python</div><div class="pg-tool-desc">Backend logic</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">Flask</div><div class="pg-tool-desc">REST APIs</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">JavaScript</div><div class="pg-tool-desc">Frontend &amp; async</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">Jekyll</div><div class="pg-tool-desc">Static sites</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">Docker</div><div class="pg-tool-desc">Containers</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">JWT Auth</div><div class="pg-tool-desc">Authentication</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">face-api.js</div><div class="pg-tool-desc">ML in browser</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">SQL</div><div class="pg-tool-desc">Data persistence</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">Git</div><div class="pg-tool-desc">Version control</div></div>
#       <div class="pg-tool-cell"><div class="pg-tool-name">REST APIs</div><div class="pg-tool-desc">Integration</div></div>
#     </div>
#   </section>
#
#   <!-- Closing -->
#   <section class="pg-close">
#     <div>
#       <div class="pg-close-sub">Final Thoughts</div>
#       <h2 class="pg-close-title">What I&rsquo;m<br><em>Taking Away</em></h2>
#     </div>
#     <div>
#       <p class="pg-close-body">I came into this year as someone who could write code but struggled to present and communicate. I&rsquo;m leaving it with a much clearer picture of how software actually gets built and shipped in the real world &mdash; in teams, under pressure, for people outside the classroom.</p>
#       <p class="pg-close-body">The tools I learned here are not just class assignments. They are the exact things I will use if I pursue software engineering seriously. And honestly, after this year, I want to.</p>
#       <p class="pg-close-body">This class gave me proof that I can build things people actually use. That means more to me than any grade.</p>
#     </div>
#   </section>
#
#   <!-- Footer -->
#   <div class="pg-footer">
#     <span class="pg-footer-name">Shayan Bhatti</span>
#     <span class="pg-footer-sub">CSP Final &mdash; Class of 2026</span>
#   </div>
#
# </div>
