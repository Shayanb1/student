# %% [markdown]
# ---
# title: CSP 1 - Final
# description: My final respective about CSP 1
# comments: post
# layout: default
# authors: Shayan B
# toc: true
# permalink: /CSP1-Final
# ---

# %% [markdown]
# # Requirments (Delete this later)
#
# ## 1. Blog/Retrospective could do the following...
# ## 2. Compare yourself to the beginning of the year
# ## 3. Remember key things from 3 sprints (Tools, Fundamentals of JavaScript/Python,  West Coast Travel or Digital Famine.
# ## 4. How N@tM went?  Did you get a comment or two you liked?
# ## 5. What do you want to do next on project, given time?
# ## 6. What do you want to learn next in CompSci?
# ## 7. Analytics review.
# ## 8. MCQ review, score, correction, and approach
# ## 9. Something cool you'd like to share.
# ## 10. Congrats on a great N@tM.  Many people commented to me about the depth of your project, and they were impressed with your technical language. (edited)

# %% [markdown]
# CSP 1 Final Review
