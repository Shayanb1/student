# %% [markdown]
# ---
# title: My progress
# description: My progress so far throughout CSP
# comments: false
# layout: default
# permalink: /progress67
# ---

# %% [markdown]
# # My coding journey ☟
#
# ## 1: I learned how to verify my tools and update each tool
#
# ### Updated my tools by either using set instructions on the opencs website or using chatgpt for instructions
#
# Verified by using the commands:
#
# - `ruby -v`
# - `bundle -v`
# - `python --version`
# - `jupyter --version`
#
# ---
#
# ## 2: Taught my teammates how to git clone repositories and fork them as well
#
# - I taught them they can type `git clone` and then the link of the repo to clone it
# - I also taught my teammates how to fork from certain repositories
#
# ### And I helped my teammates understand the differences between a forked repository and a cloned repository
#
# ---
#
# ## 3: Learned how to open a github repo on VS Code through my terminal & Activate Venv
#
# ### To open repo:
#
# Step 1: Navigate to repo - `cd ______`
#
# Step 2: Run `code .`
#
# ### To activate Venv
#
# Step 1: Navigate to repo - `cd ______`
#
# Step 2: Run `source venv/bin/activate`
#
# - This is how I set up my venv which can be different from others because I am on a mac
#
# ---
#
# ## 4: Learned how to change github themes
#
# Step 1: Change layout in `index.md` & `config.yml` to `default`
#
# Step 2: In `config.yml` change `remote_theme` to any github theme you would like to use
#
# ---
#
# ## 5: Taught teammates how to change Sprites/Backgrounds to a desired image in a game
#
# Step 1: Identify the sprite/background you would like to change
#
# Step 2: Find the path for it
#
# Step 3: Replace that path with the `relative path` of your desired image
#
# ---
#
# # Collaboration
#
# ## How has collaboration helped me in CSP?
#
# I get stuck many times when teachers give instructions, which is why I feel like it is good for me to be around people that I feel comfortable reaching out to for help. One difficult task for me to learn was how to open a github repo in VS code through my terminal, at first, even after the lecture, I had no idea what to do, but my peers around me help me learn things easily which is why I feel like collaboration is so important to me.
#
# Now collaboration isn't just asking people to help you out when you're stuck, I have learned throughout this course that collaboration can also be to work together on a project, assigning tasks in a project, making a plan, etc. Collaboration has helped me work with my peers to complete separate/similar tasks at very efficient rates which helps me have good work.
#
# ---
#
# # Reflection
#
# **What I learned:**
# Verify and update my tools, clone and fork repositories, open GitHub repos in VS Code, activate a virtual environment, and change sprites/backgrounds in a project.
#
# **Challenges I faced:**
# Opening a github repo in VS code, reaching out to others for help, planning accordingly for projects, debugging
#
# **Growth:**
# I became more confident in using GitHub and the terminal, and I also learned how to explain steps clearly when teaching my teammates.
#
# **Collaboration impact:**
# Collaboration helped me learn faster, solve problems I was stuck on, and also gave me the chance to teach my teammates skills like cloning and forking repositories.
#
# **Future impact:**
# These skills will help me work better on group projects in CSP and in future coding classes, since I now understand how to use GitHub, VS Code, and teamwork more effectively. I know that collaboration and communication will continue to be important in computer science, because coding is rarely done alone. By practicing these skills now, I will be more prepared for future classes, internships, or even real world programming jobs where teamwork and problem solving are essential.
